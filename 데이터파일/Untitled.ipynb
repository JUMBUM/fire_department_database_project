# %%
import numpy as np

# 사건테이블 날짜
ls = np.random.randint(1,31,30)

ls.sort()
ls

for x in ls:
    print("2011{}".format(x))
# Out:
# 20111
# 20111
# 20113
# 20113
# 20113
# 20114
# 20114
# 20114
# 20115
# 20115
# 20118
# 201112
# 201113
# 201114
# 201115
# 201115
# 201117
# 201122
# 201123
# 201124
# 201125
# 201125
# 201126
# 201126
# 201127
# 201128
# 201128
# 201128
# 201129
# 201130

# %%
# 사건테이블 사건 유형
ls_2 = np.random.randint(1,4,30)

ls_3 = []
for x in ls_2:
    if x == 1:
        ls_3.append('F')
    elif x == 2:
        ls_3.append('R')
    else :
        ls_3.append('A')
        
for x in ls_3: 
    print(x)
# Out:
# R
# F
# R
# R
# A
# F
# A
# R
# R
# R
# F
# R
# A
# A
# A
# A
# A
# R
# F
# R
# A
# F
# A
# A
# F
# A
# R
# A
# A
# F

# %%
# 사건테이블 지역ID
txt = """SO001
SM001
SM002
SM003
SM004
SM005
SM006
SM007
SM008
SM009
SD001
SD002
SD003
SD004
SD005
SD006
SD007"""
ls_txt = txt.split("\n")

ls_code = []
for x in range(30):
    ls_code.append(np.random.choice(ls_txt))
    
for x in ls_code:
    print(x)
# Out:
# SM002
# SD005
# SM005
# SD006
# SD004
# SM009
# SM007
# SM007
# SD003
# SM005
# SM004
# SD001
# SD004
# SD004
# SM005
# SM007
# SM008
# SD004
# SM001
# SO001
# SD006
# SD007
# SM005
# SD002
# SO001
# SM008
# SM004
# SD002
# SD006
# SD003

# %%
# 구급사건테이블 사건도착시간(time_A_ls) 병원도착시간(time_B_ls)
time_A_ls = []
time_B_ls = []
time_C_ls = []
time_ls = []
time2_ls = []
for i in range(10):
    time = np.random.randint(1,86401)
    time_ls.append(time)
    s = str(int(time%60))
    m = str(int((time - int(s))/60%60))
    h = str(int((time - int(s))/60//60))

    if int(s) < 10:
        s = "0"+s
    if int(m) < 10:
        m = "0"+m
    if int(h) < 10 :
        h = "0"+h
    
    A = "{}-{}-{}".format(h, m ,s)
    time_A_ls.append(A)

for i in range(10):
    time = np.random.randint(time_ls[i],time_ls[i]+600)
    s = str(int(time%60))
    m = str(int((time - int(s))/60%60))
    h = str(int((time - int(s))/60//60))
    
    if int(s) < 10:
        s = "0"+s
    if int(m) < 10:
        m = "0"+m
    if int(h) < 10 :
        h = "0"+h

    B = "{}-{}-{}".format(h, m ,s)
    time_B_ls.append(B)
    time2_ls.append(time)

for i in range(10):
    time = np.random.randint(time_ls[i],time_ls[i]+600)
    s = str(int(time%60))
    m = str(int((time - int(s))/60%60))
    h = str(int((time - int(s))/60//60))
    
    if int(s) < 10:
        s = "0"+s
    if int(m) < 10:
        m = "0"+m
    if int(h) < 10 :
        h = "0"+h

    C = "{}-{}-{}".format(h, m ,s)
    time_C_ls.append(C)
    
for x in time_A_ls:
    print(x)
    
print("\n\n")
for x in time_B_ls:
    print(x)
    
print("\n\n")
for x in time_C_ls:
    print(x)
# Out:
# 09-41-01
# 23-24-58
# 00-21-37
# 12-05-45
# 00-20-07
# 21-49-53
# 12-17-32
# 17-43-37
# 15-09-04
# 17-44-30
#
#
#
# 09-43-20
# 23-34-47
# 00-23-17
# 12-11-09
# 00-20-40
# 21-51-35
# 12-27-07
# 17-49-17
# 15-10-49
# 17-49-05
#
#
#
# 09-47-50
# 23-31-44
# 00-29-02
# 12-08-22
# 00-27-21
# 21-55-22
# 12-22-14
# 17-53-26
# 15-13-06
# 17-50-50

# %%
지역 = """조치원읍
연기면
연동면
부강면
금남면
장군면
연서면
전의면
전동면
소정면
한솔동
새롬동
도담동
아름동
종촌동
고운동
보람동""".split("\n")

지역ID = """SO001
SM001
SM002
SM003
SM004
SM005
SM006
SM007
SM008
SM009
SD001
SD002
SD003
SD004
SD005
SD006
SD007""".split("\n")

test = """조치원읍
전의면
부강면
연서면
전동면
도담동
고운동
아름동
종촌동
연기면
한솔동
새롬동
보람동
금남면
장군면
조치원읍
조치원읍 
전의면
부강면
연서면
전동면
전동면
도담동
고운동
아름동
종촌동
연기면
연기면
한솔동
새롬동
보람동
금남면
금남면
""".split("\n")
number_ls =[]
for x in test:
    for y in range(len(지역)):
        if x == 지역[y]:
            number_ls.append(y)

result = []
for num in number_ls:
    result.append(지역ID[num])

# %%
for x in result:
    print(x)
# Out:
# SO001
# SM007
# SM003
# SM006
# SM008
# SD003
# SD006
# SD004
# SD005
# SM001
# SD001
# SD002
# SD007
# SM004
# SM005
# SO001
# SM007
# SM003
# SM006
# SM008
# SM008
# SD003
# SD006
# SD004
# SD005
# SM001
# SM001
# SD001
# SD002
# SD007
# SM004
# SM004

# %%
len(test)
# Out:
# 34

# %%
len(result)
# Out:
# 32

# %%
# 구급사건테이블 사건도착시간(time_A_ls) 병원도착시간(time_B_ls)
time_A_ls = []
time_B_ls = []
time_C_ls = []
time_ls = []
time2_ls = []
for i in range(30):
    time = np.random.randint(1,86401)
    time_ls.append(time)
    s = str(int(time%60))
    m = str(int((time - int(s))/60%60))
    h = str(int((time - int(s))/60//60))

    if int(s) < 10:
        s = "0"+s
    if int(m) < 10:
        m = "0"+m
    if int(h) < 10 :
        h = "0"+h
    
    A = "{}-{}-{}".format(h, m ,s)
    time_A_ls.append(A)

for x in time_A_ls:
    print(x)
# Out:
# 05-05-11
# 00-37-14
# 09-48-05
# 14-06-51
# 14-48-29
# 21-07-46
# 03-03-18
# 19-34-13
# 10-57-45
# 13-54-16
# 04-27-30
# 00-19-50
# 19-17-21
# 21-39-00
# 20-58-28
# 23-17-25
# 11-17-31
# 04-17-15
# 01-24-35
# 12-11-58
# 01-28-15
# 19-27-44
# 18-32-28
# 00-12-19
# 06-09-07
# 05-39-27
# 00-49-07
# 08-39-12
# 16-24-35
# 14-09-47

# %%
세종_지역ID = """SO001
SM001
SM002
SM003
SM004
SM005
SM006
SM007
SM008
SM009
SD001
SD002
SD003
SD004
SD005
SD006
SD007""".split("\n")

사건_지역ID = """SD007
SM009
SD005
SM006
SM008
SO001
SD002
SD005
SD003
SM001
SM005
SD005
SD007
SD001
SO001
SM006
SM004
SM006
SM001
SM009
SD004
SD006
SD003
SD002
SD004
SM004
SM003
SD006
SD001
SM004""".split("\n")

관할구역_지역ID = """SO001
SM007
SM009
SM003
SM002
SM006
SM008
SD003
SD006
SD004
SD005
SM001
SD001
SD002
SD007
SM004
SM005
SO001
SO001
SM007
SM009
SM009
SM003
SM002
SM002
SM006
SM008
SM008
SD003
SD006
SD004
SD005
SM001
SM001
SD001
SD002
SD007
SM004
SM004""".split("\n")

관할구역_소방서ID = """JCO-A
JCO-A
JCO-A
JCO-A
JCO-A
JCO-A
JCO-A
SJ-A
SJ-A
SJ-A
SJ-A
SJ-A
SJ-A
SJ-A
SJ-A
SJ-A
SJ-A
JCO-B
OL-C
JO-B
JO-B
SJM-C
BG-B
BG-B
ODM-C 
OS-B
OS-B
JDM-C
OJ-B
OL-B
OL-B
OL-B
OL-B
OGM-C
HS-B
HS-B
BL-B
BL-B
GNM-C""".split("\n")

관할구역_dict = {}
for 지역ID in 세종_지역ID:
    
    i_ls = []
    for i in range(len(관할구역_지역ID)):
        if 지역ID == 관할구역_지역ID[i]:
            i_ls.append(i)
    
    소방서__ = []
    for ii in i_ls:
        소방서__.append(관할구역_소방서ID[ii])
    
    관할구역_dict.update({지역ID:소방서__})


관할구역_dict_keys = list(관할구역_dict.keys())
관할구역_dict_values = list(관할구역_dict.values())
abc_ls = []

for 지역ID in 사건_지역ID:
    
    i_ls = []
    for i in range(len(관할구역_dict_keys)):
        if 지역ID == 관할구역_dict_keys[i]:
            i_ls.append(i)
            
      
    for ii in i_ls:
        abc = np.random.choice(관할구역_dict_values[ii])
        abc_ls.append(abc)
        
for x in abc_ls:
    print(x)
# Out:
# SJ-A
# JCO-A
# SJ-A
# OS-B
# OS-B
# JCO-B
# HS-B
# OL-B
# SJ-A
# SJ-A
# SJ-A
# OL-B
# BL-B
# HS-B
# JCO-B
# OS-B
# GNM-C
# OS-B
# OL-B
# JCO-A
# SJ-A
# SJ-A
# OJ-B
# HS-B
# OL-B
# SJ-A
# JCO-A
# SJ-A
# SJ-A
# SJ-A

# %%
for x in np.random.randint(40, 201, 7):
    print(x)
# Out:
# 45
# 82
# 153
# 74
# 63
# 136
# 51

# %%
len(관할구역_지역ID)
# Out:
# 41

# %%
aaaaaa = np.random.randint(0, 10, 300)

qqq = []
for aaa in aaaaaa:
    aaa= int(aaa)
    qqq.append(np.random.randint(aaa, aaa//3*10+10))
    
for x in qqq:
    print(x)
# Out:
# 8
# 14
# 8
# 4
# 9
# 5
# 10
# 7
# 9
# 5
# 24
# 8
# 14
# 2
# 6
# 11
# 13
# 22
# 5
# 17
# 2
# 16
# 12
# 11
# 10
# 17
# 19
# 19
# 28
# 5
# 6
# 16
# 15
# 15
# 33
# 3
# 2
# 16
# 9
# 16
# 18
# 15
# 5
# 23
# 18
# 31
# 18
# 12
# 17
# 15
# 21
# 8
# 35
# 18
# 15
# 28
# 18
# 16
# 7
# 15
# 14
# 4
# 1
# 26
# 19
# 11
# 14
# 16
# 8
# 17
# 27
# 12
# 2
# 6
# 6
# 12
# 7
# 3
# 15
# 11
# 9
# 2
# 10
# 35
# 6
# 1
# 12
# 21
# 6
# 16
# 19
# 10
# 5
# 10
# 7
# 12
# 19
# 4
# 8
# 16
# 6
# 12
# 27
# 26
# 9
# 6
# 9
# 9
# 4
# 3
# 18
# 2
# 21
# 29
# 5
# 6
# 16
# 17
# 20
# 4
# 6
# 19
# 19
# 25
# 7
# 11
# 12
# 12
# 12
# 3
# 17
# 25
# 21
# 5
# 27
# 19
# 19
# 25
# 5
# 16
# 17
# 19
# 9
# 11
# 8
# 3
# 13
# 12
# 17
# 9
# 15
# 2
# 19
# 5
# 16
# 24
# 10
# 17
# 22
# 17
# 5
# 27
# 12
# 9
# 6
# 0
# 26
# 19
# 15
# 5
# 7
# 21
# 6
# 4
# 9
# 24
# 4
# 5
# 1
# 4
# 29
# 10
# 7
# 9
# 5
# 15
# 19
# 3
# 19
# 8
# 1
# 17
# 5
# 4
# 9
# 12
# 16
# 7
# 4
# 7
# 13
# 6
# 14
# 6
# 15
# 22
# 15
# 24
# 13
# 1
# 19
# 18
# 5
# 3
# 5
# 9
# 11
# 11
# ...

# %%
import numpy as np

time_A_ls = []

time_ls = []
for i in range(30):
    time = np.random.randint(1,86401)
    time_ls.append(time)
    s = str(int(time%60))
    m = str(int((time - int(s))/60%60))
    h = str(int((time - int(s))/60//60))

    if int(s) < 10:
        s = "0"+s
    if int(m) < 10:
        m = "0"+m
    if int(h) < 10 :
        h = "0"+h
    
    A = "{}{}{}".format(h, m ,s)
    time_A_ls.append(A)
    
for x in time_A_ls:
    print(x)
# Out:
# 044902
# 151218
# 065520
# 022727
# 035218
# 192702
# 044305
# 232756
# 135313
# 142542
# 234309
# 051921
# 013843
# 055624
# 083702
# 082222
# 044359
# 144207
# 204620
# 143220
# 035043
# 020214
# 102722
# 220018
# 231049
# 215729
# 034912
# 145936
# 173508
# 153303

# %%
직원""""""
